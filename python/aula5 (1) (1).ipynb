# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
page = requests.get('https://jornaldebrasilia.com.br/blogs-e-colunas/educar-acao/')
soup = BeautifulSoup(page.text, 'html.parser')

# %%
noticias = soup.find_all('article')
bloco_noticias = soup.find(class_='list-cat-post')

# %%
for noticia in noticias:
  link = noticia.find('a').attrs['href']
  titulo = noticia.find(class_="title").text
  #só para pegar o título
  datas = noticia.find('p').text.split(' -')[0]
  print(link)
  print(titulo)
  print(data)
# Out:
# https://jornaldebrasilia.com.br/blogs-e-colunas/educar-acao/aprimorando-a-comunicacao-entre-pais-e-professores-para-melhorar-o-sucesso-do-aluno/
# Aprimorando a comunicação entre pais e professores para melhorar o sucesso do aluno
# []
# https://jornaldebrasilia.com.br/blogs-e-colunas/educar-acao/tres-maneiras-de-ensinar-aos-alunos-que-o-fracasso-e-necessario-para-aprender/
# Três maneiras de ensinar aos alunos que o fracasso é necessário para aprender
# []
# https://jornaldebrasilia.com.br/blogs-e-colunas/educar-acao/sete-dicas-para-incentivar-seus-alunos-a-ler/
# Sete dicas para incentivar seus alunos a ler
# []
# https://jornaldebrasilia.com.br/blogs-e-colunas/educar-acao/o-exodo-do-professor-e-hora-das-escolas-repensarem-suas-estrategias-de-recrutamento-e-retencao/
# O êxodo do professor: é hora das escolas repensarem suas estratégias de recrutamento e retenção?
# []
# https://jornaldebrasilia.com.br/blogs-e-colunas/educar-acao/trazendo-ferramentas-de-ia-para-a-sala-de-aula/
# ...

# %%
soup.find_all(class_= 'page-numbers')
# Out:
# [<span aria-current="page" class="page-numbers current">1</span>,
#  <a class="page-numbers" href="https://jornaldebrasilia.com.br/blogs-e-colunas/educar-acao/page/2/">2</a>,
#  <a class="page-numbers" href="https://jornaldebrasilia.com.br/blogs-e-colunas/educar-acao/page/3/">3</a>,
#  <span class="page-numbers dots">…</span>,
#  <a class="page-numbers" href="https://jornaldebrasilia.com.br/blogs-e-colunas/educar-acao/page/8/">8</a>,
#  <a class="next page-numbers" href="https://jornaldebrasilia.com.br/blogs-e-colunas/educar-acao/page/2/">&gt;</a>]

# %%
soup.find(class_='next').attrs['href']
# Out:
# 'https://jornaldebrasilia.com.br/blogs-e-colunas/educar-acao/page/2/'

# %%
link = soup.find(class_='next').attrs['href']
page = requests.get(link)
soup = BeautifulSoup(page.text, 'html.parser')

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="pt-BR">\n <head>\n  <meta content="2WPUbMoVhJ66bR0hSzNShh0nW2qJqPiYgQa2kUGe-f8" name="google-site-verification"/>\n  <script src="/cdn-cgi/apps/head/EKFjdbBUMFBohBh8Fv9d3ENAcL4.js">\n  </script>\n  <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-46209201-1">\n  </script>\n  <script>\n   window.dataLayer = window.dataLayer || [];\n  function gtag(){dataLayer.push(arguments);}\n  gtag(\'js\', new Date());\n  gtag(\'config\', \'UA-46209201-1\');\n  </script>\n  <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-LWZRG50XP4">\n  </script>\n  <script>\n   window.dataLayer = window.dataLayer || [];\n  function gtag(){dataLayer.push(arguments);}\n  gtag(\'js\', new Date());\n  gtag(\'config\', \'G-LWZRG50XP4\');\n  </script>\n  <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-858034853">\n  </script>\n  <script>\n   window.dataLayer = window.dataLayer || [];\n  function gtag(){dataLayer.push(arguments);}\
# ...

# %%
#while pega o valor "verdade"
